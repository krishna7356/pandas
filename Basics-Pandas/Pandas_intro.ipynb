# %% [markdown]
# # Welcome to the Ultimate Pandas Introduction
#
# Learn the basics on the pandas python library in this tutorial!

# %%
import pandas as pd  #importing panda as pd
import numpy as np   #impporting numpy as np

# %% [markdown]
# ## series
#
# series: Pandas Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.).

# %%
my_data=['Bike','motor','car','cycle']
print(pd.Series(my_data))
# Out:
# 0     Bike
# 1    motor
# 2      car
# 3    cycle
# dtype: object

# %%
my_Data2 =[12,34,56,87,6]
print(pd.Series(my_Data2))
# Out:
# 0    12
# 1    34
# 2    56
# 3    87
# 4     6
# dtype: int64

# %% [markdown]
# ## DataFrame
# Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure.

# %%
mydfdata = [('Boat', 0), ('Car', 4), ('Bike',2), ('Truck', 4)]
mydf = pd.DataFrame(mydfdata,columns=['vehicle','no of wheels'])
print(mydf)
# Out:
#   vehicle  no of wheels
# 0    Boat             0
# 1     Car             4
# 2    Bike             2
# 3   Truck             4

# %%
mydf.dtypes
# Out:
# vehicle         object
# no of wheels     int64
# dtype: object

# %% [markdown]
# ## Reading in Data

# %%
# reading .csv file from the below path
df =pd.read_csv( r"C:\Users\Krishna\OneDrive\Desktop\python\study\panda\MrBeast_youtube_stats.csv")

# %% [markdown]
# ## Inspect Data

# %%
df.head()   # it will return frist five rows from the file
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2021-04-24 20:00:00+00:00  youtube#video               861   84717282.0
# 1  2021-12-18 21:00:00+00:00  youtube#video               729   32090178.0
# ...

# %%
df.tail()   # it will return last five rows from the file
# Out:
#               id                                              title  \
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 242  Yup, another very pointless video ▻ Subscribe?...
# 243  Look at this - http://gyazo.com/8852509d2350db...
# 244  The beginning of the video is a little off top...
# 245  His channel - https://www.youtube.com/user/the...
# 246  In this video I talk about being an uber drive...
#
#                    publishTime     kind_stats  duration_seconds  viewCount  \
# 242  2015-04-26 21:26:36+00:00  youtube#video               216    16312.0
# ...

# %%
df.dtypes   # return all the deatils about data it include column name and it's data type
# Out:
# id                                        object
# title                                     object
# description                               object
# publishTime                               object
# kind_stats                                object
# duration_seconds                           int64
# viewCount                                float64
# likeCount                                float64
# commentCount                             float64
# thumbnails.default.url                    object
# thumbnails.default.width                 float64
# thumbnails.default.height                float64
# thumbnails.medium.url                     object
# thumbnails.medium.width                  float64
# thumbnails.medium.height                 float64
# thumbnails.high.url                       object
# thumbnails.high.width                    float64
# thumbnails.high.height                   float64
# contentDetails.duration                   object
# ...

# %%
df.describe() # statistics of the Series or Dataframe provided
# Out:
#        duration_seconds     viewCount     likeCount   commentCount  \
# count        247.000000  2.460000e+02  2.440000e+02     245.000000
# mean        1886.234818  5.084638e+07  1.610498e+06   75562.783673
# std         8642.188728  4.062672e+07  1.879529e+06   85356.537127
# min            0.000000  1.395400e+04  3.700000e+02      59.000000
# 25%          425.500000  1.406442e+07  4.348780e+05   21552.000000
# 50%          776.000000  4.904782e+07  1.358232e+06   60701.000000
# 75%          923.000000  8.125392e+07  2.294378e+06   99670.000000
# max        85686.000000  1.787632e+08  1.904943e+07  726861.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                     246.0                      246.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %%
df.shape      # display number of Rows and Columns
# Out:
# (247, 26)

# %%
df.columns    # show all column name in list
# Out:
# Index(['id', 'title', 'description', 'publishTime', 'kind_stats',
#        'duration_seconds', 'viewCount', 'likeCount', 'commentCount',
#        'thumbnails.default.url', 'thumbnails.default.width',
#        'thumbnails.default.height', 'thumbnails.medium.url',
#        'thumbnails.medium.width', 'thumbnails.medium.height',
#        'thumbnails.high.url', 'thumbnails.high.width',
#        'thumbnails.high.height', 'contentDetails.duration',
#        'contentDetails.dimension', 'topicDetails.topicCategories',
#        'snippet.defaultLanguage', 'localizations.en.title',
#        'localizations.en.description', 'snippet.tags',
#        'contentDetails.contentRating.ytRating'],
#       dtype='object')

# %% [markdown]
# ## Columns and Rows

# %%
df["viewCount"]   # accessing single column dataframe["columnname"]
# Out:
# 0       84717282.0
# 1       32090178.0
# 2              NaN
# 3      101745632.0
# 4       50008942.0
#           ...
# 242        16312.0
# 243        15740.0
# 244        18502.0
# 245        16627.0
# 246        18773.0
# Name: viewCount, Length: 247, dtype: float64

# %%
df[["id","title"]] # accessing multiple columns : df[["coumnname_1","columnname_2"]]
# Out:
#               id                                              title
# 0    TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1    00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2            NaN                                            MrBeast
# 3    ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4    cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ..           ...                                                ...
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
# [247 rows x 2 columns]

# %%
# df.head()
df.loc[4]         # access data in the fourth row
# Out:
# id                                                                             cExLQ1o2pDw
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# ...

# %%
df = df.set_index('id')  # set id column as index

# %% [markdown]
# ## Subsetting Data

# %% [markdown]
# The process of picking a set of desired rows and columns from a data frame .

# %%
# Subsetting Columns
df = df[['title', 'description', 'publishTime',
         'duration_seconds', 'viewCount', 'likeCount',
         'commentCount']]

# %%
df.shape     # number of columns change to selected columns
# Out:
# (247, 7)

# %%
# Subsetting using loc
df_subset1 = df.loc[df['viewCount'] > 1_000_000]    # sorting the rows based on a condtion(view count >1000000)

# %% [markdown]
# ##### subsetting the same condition using query

# %%
df_subset2 = df.query('viewCount > 1000000')

# %%
df_subset2 == df_subset1  # both files are same
# Out:
#              title  description  publishTime  duration_seconds  viewCount  \
# id
# TQHEJj68Jew   True         True         True              True       True
# 00NgUctWoLQ   True         True         True              True       True
# ayXxwJJId_c   True         True         True              True       True
# cExLQ1o2pDw   True         True         True              True       True
# GLoeAJUcz38   True         True         True              True       True
# ...            ...          ...          ...               ...        ...
# xWcldHxHFpo   True         True         True              True       True
# mGIpOtncmSM   True         True         True              True       True
# 9CVwXBYVqVk   True         True         True              True       True
# 2IGxSOfsBok   True         True         True              True       True
# bEIK5ni_Pzs   True         True         True              True       True
#
#              likeCount  commentCount
# id
# ...

# %%
df = df.loc[~df['likeCount'].isna()]   # removing Nan values from data frame
df
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount           float64
# commentCount        float64
# dtype: object

# %% [markdown]
# ## Casting dtypes
# covert x varible from one to another( float, integer or string (String should be a whole number) variable)

# %%
df['viewCount'] = df['viewCount'].astype('int')  #convert data type float64 to int
df['likeCount'] = df['likeCount'].astype('int')

# %%
df['publishTime'] = pd.to_datetime(df['publishTime'])  # convert  the  datatype into datetime

# %%
df['likeCount'] = pd.to_numeric(df['likeCount'].astype('str')) #Convert argument to a numeric type

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int32
# likeCount                         int64
# commentCount                    float64
# dtype: object

# %% [markdown]
# ## Creating new column

# %%
df['like_to_view_ratio'] = df['likeCount'] / df['viewCount']  # create new column like_to_view_ratio

# %% [markdown]
# ## Creating new column

# %%
df_to_append = df.tail(1)    #create a copy of final row data

# %%
df_concat = pd.concat([df, df_to_append])  # concation with existing data

# %% [markdown]
# ## Plot Examples

# %%
import matplotlib.pylab as plt
plt.style.use('ggplot')

# %%
df['viewCount'].plot(kind='hist', bins=100,
                     title='Distribution of View Count',
                     figsize=(15, 5))
# Out:
# <AxesSubplot: title={'center': 'Distribution of View Count'}, ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='viewCount', y='likeCount', title='View vs Like Count')
# Out:
# <AxesSubplot: title={'center': 'View vs Like Count'}, xlabel='viewCount', ylabel='likeCount'>

# %% [markdown]
# ## Save our output

# %%
df.to_csv('processed_data.csv')
